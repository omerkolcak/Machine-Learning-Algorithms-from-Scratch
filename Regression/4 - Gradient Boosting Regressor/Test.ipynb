# %%
from GradientBoostingRegressor import GradientBoostingRegressor

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    Brand  Year  Configuration  Strings  Made in  Type  Body Shape  \
# 0     18    12              1        1        5     2          14
# 1      4    13              1        1        3     2          14
# 2     18    13              1        1        2     2          14
# 3     18    12              1        2        5     2          14
# 4     18    10              1        1        5     2          14
#
#    Body Material  Neck Joint  Neck Material  ...  Switch  Knobs  \
# 0              2           1              2  ...       1      1
# 1              6           1              2  ...       1      1
# 2              2           1              2  ...       1      1
# 3              2           1              2  ...       1      1
# 4              2           1              2  ...       1      1
#
#    Volume Controls  Tone Controls  Top Pickup Brand  Pickups Power  \
# 0                1              1                 1              6
# ...

# %%
x = df.drop("Price",axis=1)
y = df['Price'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y_train = pd.DataFrame(y_train,columns=['Price'],index=x_train.index)

# %%
gb = GradientBoostingRegressor(max_depth=3,n_estimators=10)

# %%
gb.fit(x_train,y_train,learning_rate=0.25)
# Out:
# Estimator 1 is being trained...
# C:\Users\Omer\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
test_preds = gb.predict(x_test)
# Out:
# C:\Users\Omer\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(test_preds,y_test)
# Out:
# 0.21119186858512579

# %%
test_preds
# Out:
# array([1125.39054208, 1125.39054208,  573.03616187, 1959.54854066,
#         939.07053081, 1249.41529709, 1079.21797791,  830.91723016,
#         896.41675274, 1103.27733262, 1084.92719756, 1699.0505942 ,
#         691.87905737,  418.65404783, 1048.9038339 ,  638.52505311,
#        1196.00373194, 1038.05019984, 1192.42207286,  690.72267548,
#        1108.06924913, 1121.86398575, 1207.46042632,  252.61565707,
#         717.07625614,  623.05097846,  882.60953982,  397.97385821,
#        1715.85953725, 1034.71872465, 1005.03727504, 1054.9592902 ,
#        1262.44854099, 1112.9105111 ,  410.52297024, 1176.4474782 ,
#        1737.97405706, 1961.59476216,  697.92615292, 1267.61795556,
#        1038.05019984,  717.16167354,   81.78877275, 1276.98902722,
#         607.75130873, 1015.6892889 , 2092.28596089,  281.78193947,
#        1916.26373363, 1468.48133116,  602.61562138,  623.05097846,
#         445.00762849, 1311.07087931,  850.81038048, 2028.77104547,
# ...

# %%
y_test
# Out:
# array([ 956.76      , 1213.8       ,  299.235     , 1843.242     ,
#         712.98      , 1124.502     ,  963.9       ,  661.6425    ,
#         811.136     ,  950.618     , 1331.89      , 1634.74333333,
#         380.7425    ,  221.995     , 1015.5425    ,  625.36      ,
#         913.9525    ,  948.004     , 1250.662     ,  738.142     ,
#        1543.4175    ,  942.49      , 1286.39333333,  282.54      ,
#         823.514     ,  751.075     ,  827.58      ,  476.028     ,
#        1871.028     , 1217.79666667, 1032.99666667,  900.66      ,
#        1749.55      ,  880.84      ,  216.985     , 1038.61666667,
#        1592.0275    , 2225.65      ,  563.97      , 1455.0525    ,
#        1199.7425    ,  522.498     ,  198.052     , 1313.5675    ,
#         629.4375    ,  926.905     , 1838.6175    ,  334.7       ,
#        1712.936     , 1484.524     ,  457.66666667,  657.548     ,
#         351.546     , 1130.885     ,  987.122     , 2164.428     ,
# ...
