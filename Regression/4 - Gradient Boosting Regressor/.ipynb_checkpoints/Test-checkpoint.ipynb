# %%
from GradientBoostingRegressor import GradientBoostingRegressor

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("dataset.csv")
df.head()
# Out:
#    Brand  Year  Configuration  Strings  Made in  Type  Body Shape  \
# 0     18    12              1        1        5     2          14
# 1      4    13              1        1        3     2          14
# 2     18    13              1        1        2     2          14
# 3     18    12              1        2        5     2          14
# 4     18    10              1        1        5     2          14
#
#    Body Material  Neck Joint  Neck Material  ...  Switch  Knobs  \
# 0              2           1              2  ...       1      1
# 1              6           1              2  ...       1      1
# 2              2           1              2  ...       1      1
# 3              2           1              2  ...       1      1
# 4              2           1              2  ...       1      1
#
#    Volume Controls  Tone Controls  Top Pickup Brand  Pickups Power  \
# 0                1              1                 1              6
# 1                1              1                 1              1
# 2                1              1                 1              1
# 3                1              1                 1              6
# 4                1              1                 1              3
#
#    Locking Tuners  Bridge Type  Tremolo     Price
# 0               0            6        1  1357.600
# 1               1            6        1  2308.628
# 2               0            6        1  1214.245
# 3               0            6        1  1487.980
# 4               0            6        1  1265.148
#
# [5 rows x 29 columns]

# %%
x = df.drop("Price",axis=1)
y = df['Price'].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
y_train = pd.DataFrame(y_train,columns=['Price'],index=x_train.index)

# %%
gb = GradientBoostingRegressor(max_depth=3,n_estimators=5)

# %%
gb.fit(x_train,y_train,learning_rate=0.5)
# Out:
# Estimator 1 is being trained...

# %%
test_preds = gb.predict(x_test)
# Out:
# 1157

# %%
y_train - y_train.values
# Out:
#       Price
# 1430    0.0
# 353     0.0
# 1089    0.0
# 915     0.0
# 682     0.0
# ...     ...
# 1095    0.0
# 1130    0.0
# 1294    0.0
# 860     0.0
# 1126    0.0
#
# [1156 rows x 1 columns]
