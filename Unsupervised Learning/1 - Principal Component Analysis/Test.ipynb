# %%
from pca import PCA

import matplotlib.pyplot as plt
from sklearn.datasets import load_iris,load_breast_cancer

# %% [markdown]
# <h2> Iris Dataset </h2>

# %%
dataset = load_iris()

X = dataset.data
y = dataset.target

# %%
pca = PCA(k=2)

X_transformed = pca.fit_transform(X)

# %%
plt.scatter(X_transformed[:,0],X_transformed[:,1],c=y)

# %% [markdown]
# <h2> Breast Cancer Dataset </h2>

# %%
dataset = load_breast_cancer()

X = dataset.data
y = dataset.target

# %%
X.shape
# Out:
# (569, 30)

# %%
pca = PCA(k=2)

X_transformed = pca.fit_transform(X)

# %%
plt.scatter(X_transformed[:,0],X_transformed[:,1],c=y)
plt.title("PCA for Breast Cancer Dataset")
# Out:
# Text(0.5, 1.0, 'PCA for Breast Cancer Dataset')
